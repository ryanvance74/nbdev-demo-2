# %%
#| hide
from nbdev_demo_2.core import *

# %% [markdown]
# # nbdev-demo-2
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install nbdev_demo_2 in Development mode

# %% [markdown]
# ```sh
# # make sure nbdev_demo_2 package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to nbdev_demo_2
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/ryanvance74/nbdev-demo-2.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c ryanvance74 nbdev_demo_2
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install nbdev_demo_2
# ```
#
#
# [repo]: https://github.com/ryanvance74/nbdev-demo-2
# [docs]: https://ryanvance74.github.io/nbdev-demo-2/
# [pypi]: https://pypi.org/project/nbdev-demo-2/
# [conda]: https://anaconda.org/ryanvance74/nbdev-demo-2

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/ryanvance74/nbdev-demo-2
# [docs]: https://ryanvance74.github.io/nbdev-demo-2/
# [pypi]: https://pypi.org/project/nbdev-demo-2/
# [conda]: https://anaconda.org/ryanvance74/nbdev-demo-2

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
